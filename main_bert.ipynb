# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# %cd /content/gdrive/My Drive/Research/UOH/BHI2024
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/My Drive/Research/UOH/BHI2024

# %%
# !pip install scipy==1.10.1
# !pip install gensim==4.2.0 --q
# !pip install editdistance==0.6.1 --q
# !pip install lingpy --q
# !pip install accelerate --q
# !pip install transformers --q
# !pip install setfit --q
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 48.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.6/280.6 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 18.5 MB/s eta 0:00:00
# ...

# %%
#!python main.py OBESIDAD 1 5 bert-cregex AL True
# !python main.py OBESIDAD_TIPOS 1 5 bert-cregex AL True
# !python main.py FUMADOR 1 5 bert-cregex AL True
# Out:
# 2025-01-04 11:13:28.194520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-04 11:13:28.229366: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-04 11:13:28.241358: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-04 11:13:28.263472: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#xyz

# %%
'''
# !python main.py OBESIDAD 1 1 bert PL False
# !python main.py OBESIDAD_TIPOS 1 1 bert PL False
# !python main.py FUMADOR 1 1 bert PL False

# !python main.py OBESIDAD 1 1 bert-cregex AL False
# !python main.py OBESIDAD_TIPOS 1 1 bert-cregex AL False
# !python main.py FUMADOR 1 1 bert-cregex AL False

# !python main.py OBESIDAD 1 1 bert AL False
# !python main.py OBESIDAD_TIPOS 1 1 bert AL False
# !python main.py FUMADOR 1 1 bert AL False
'''
# Out:
# '\n!python main.py OBESIDAD 1 1 bert PL False\n!python main.py OBESIDAD_TIPOS 1 1 bert PL False\n!python main.py FUMADOR 1 1 bert PL False\n\n!python main.py OBESIDAD 1 1 bert-cregex AL False\n!python main.py OBESIDAD_TIPOS 1 1 bert-cregex AL False\n!python main.py FUMADOR 1 1 bert-cregex AL False\n\n!python main.py OBESIDAD 1 1 bert AL False\n!python main.py OBESIDAD_TIPOS 1 1 bert AL False\n!python main.py FUMADOR 1 1 bert AL False\n'
