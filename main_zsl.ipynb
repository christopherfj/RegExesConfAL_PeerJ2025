# %%
'''
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# %cd /content/gdrive/My Drive/Research/UOH/BHI2024
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/gdrive/', force_remount=True)\n%cd /content/gdrive/My Drive/Research/UOH/BHI2024\n"

# %%
'''
# !pip install scipy==1.10.1
# !pip install gensim==4.2.0 --q
# !pip install editdistance==0.6.1 --q
# !pip install lingpy --q
# !pip install accelerate --q
# !pip install transformers --q
# !pip install setfit --q
'''
# Out:
# '\n!pip install scipy==1.10.1\n!pip install gensim==4.2.0 --q\n!pip install editdistance==0.6.1 --q\n!pip install lingpy --q\n!pip install accelerate --q\n!pip install transformers --q\n!pip install setfit --q\n'

# %%
'''
# !python main.py OBESIDAD 1 5 zsl-cregex AL True
# !python main.py OBESIDAD_TIPOS 1 5 zsl-cregex AL True
# !python main.py FUMADOR 1 5 zsl-cregex AL True
'''

# %run main.py OBESIDAD 1 5 zsl-cregex AL True
# %run main.py OBESIDAD_TIPOS 1 5 zsl-cregex AL True
# %run main.py FUMADOR 1 5 zsl-cregex AL True
# Out:
# OBESIDAD
# fold: 1
# CURVE: RESULTS
# MODEL: zsl-cregex
# CREGEX...fit
# PATH-fregex... G:\Mi unidad\Research\UOH\BHI2024
# sw_cpp_OBESIDAD.exe was removed
# zsl...fit
# zsl...predict
# CREGEX...predict
# fold: 2
# CURVE: RESULTS
# MODEL: zsl-cregex
# CREGEX...fit
# PATH-fregex... G:\Mi unidad\Research\UOH\BHI2024
# TOKENS_OBESIDAD.txt was removed
# DATOSX_OBESIDAD.txt was removed
# CORPUSX_OBESIDAD.txt was removed
# CLASESX_OBESIDAD.txt was removed
# sw_cpp_OBESIDAD.exe was removed
# zsl...fit
# zsl...predict
# CREGEX...predict
# fold: 3
# CURVE: RESULTS
# MODEL: zsl-cregex
# CREGEX...fit
# PATH-fregex... G:\Mi unidad\Research\UOH\BHI2024
# TOKENS_OBESIDAD.txt was removed
# DATOSX_OBESIDAD.txt was removed
# CORPUSX_OBESIDAD.txt was removed
# CLASESX_OBESIDAD.txt was removed
# sw_cpp_OBESIDAD.exe was removed
# zsl...fit
# zsl...predict
# CREGEX...predict
# fold: 4
# CURVE: RESULTS
# MODEL: zsl-cregex
# CREGEX...fit
# PATH-fregex... G:\Mi unidad\Research\UOH\BHI2024
# ...

# %%
'''
# !python main.py OBESIDAD 1 1 zsl PL False
# !python main.py OBESIDAD_TIPOS 1 1 zsl PL False
# !python main.py FUMADOR 1 1 zsl PL True

# !python main.py OBESIDAD 1 1 zsl AL False
# !python main.py OBESIDAD_TIPOS 1 1 zsl AL False
# !python main.py FUMADOR 1 1 zsl AL True

# !python main.py OBESIDAD 1 1 zsl-cregex AL False
# !python main.py OBESIDAD_TIPOS 1 1 zsl-cregex AL False
# !python main.py FUMADOR 1 1 zsl-cregex AL True
'''

# %run main.py OBESIDAD 1 1 zsl PL False
# %run main.py OBESIDAD_TIPOS 1 1 zsl PL False
# %run main.py FUMADOR 1 1 zsl PL False

# %run main.py OBESIDAD 1 1 zsl AL False
# %run main.py OBESIDAD_TIPOS 1 1 zsl AL False
# %run main.py FUMADOR 1 1 zsl AL False

# %run main.py OBESIDAD 1 1 zsl-cregex AL False
# %run main.py OBESIDAD_TIPOS 1 1 zsl-cregex AL False
# %run main.py FUMADOR 1 1 zsl-cregex AL False
